# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshadaE25/Test-1/blob/main/Binary_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Binary classfication - Booking cancellation Data

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ### Step 1 - Data ingesions

# %%
import pandas as pd
url1 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/booking_train.csv"
df = pd.read_csv(url1)
df.head()
# Out:
#    id  no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0   0             2               0                     0                  2
# 1   1             2               0                     1                  2
# 2   2             2               0                     0                  1
# 3   3             1               0                     0                  2
# 4   4             2               0                     1                  0
#
#    type_of_meal_plan  required_car_parking_space  room_type_reserved  \
# 0                  1                           0                   0
# 1                  0                           0                   0
# 2                  0                           0                   0
# 3                  1                           0                   0
# 4                  0                           0                   0
#
#    lead_time  arrival_year  arrival_month  arrival_date  market_segment_type  \
# ...
